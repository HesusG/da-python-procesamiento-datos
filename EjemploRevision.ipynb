# %% [markdown]
# Hola &#x1F600;
#
# Soy **Hesus Garcia**  como "Jesús" pero con H. Sé que puede ser confuso al principio, pero una vez que lo recuerdes, ¡nunca lo olvidarás! &#x1F31D;	. Como revisor de código, estoy emocionado de examinar tus proyectos y ayudarte a mejorar tus habilidades en programación. si has cometido algún error, no te preocupes, pues ¡estoy aquí para ayudarte a corregirlo y hacer que tu código brille! &#x1F31F;.
# **¡Empecemos!**  &#x1F680;

# %% [markdown]
# ![Study Plan School Docs Banner in Bright Green Lime Green Pink Bright Modern Style.png](data:image/png;base64,...)

# %% [markdown]
# # **Proyecto de Análisis de Datos: Análisis de Ataques de Seguridad Cibernética**
#
# ## **Introducción**
#
# #### La Importancia de la Seguridad Cibernética en la Era Digital
#
# **En la era digital actual, la información se ha convertido en un activo valioso tanto para empresas como para individuos.** Sin embargo, esta creciente dependencia en el mundo digital ha desencadenado un aumento en los ataques cibernéticos, los cuales pueden acarrear consecuencias significativas, como la pérdida de datos confidenciales, interrupciones en los servicios y daños a la reputación.
#
# #### Evolución de los Ataques Cibernéticos
#
# Desde su aparición en 1988 con el **gusano de Morris**, que causó daños considerables a las computadoras y su conexión a internet, los ataques cibernéticos han evolucionado drásticamente en términos de **peligrosidad** y **frecuencia**. Tan solo en el año **2023**, se registraron más de **800,000 ciberataques**, lo que equivale a un promedio de **2,220 ataques diarios** (Charlton, 2024).
#
# #### Impacto a Nivel Individual y Organizacional
#
# - **Individual:** El caso de Joshua Schulte, condenado a 40 años de prisión por robar información clasificada de la CIA, ejemplifica el impacto personal de los ataques cibernéticos.
#
# - **Organizacional:** El informe "Costo de una Brecha de Datos" de IBM (2023) revela que al sector público le cuesta en promedio 2.07 millones de dólares enfrentar estos ataques, mostrando las consecuencias financieras para las organizaciones.
#
# #### Desafíos del Crecimiento Exponencial de la Información
#
# El **crecimiento exponencial de la información** en el panorama digital actual plantea desafíos significativos en términos de **seguridad cibernética**. En **2020**, se generaron **64.2 zettabytes** de datos a nivel mundial, lo que representa una cantidad masiva de información digital. Se proyecta que esta cifra supere los **180 zettabytes para 2025** (Statista, 2023). Este aumento en la generación de datos subraya la urgente necesidad de desarrollar **protocolos eficientes y sólidos** para gestionar la información de manera segura, dado que está constantemente expuesta a diversos **ataques cibernéticos**.
#
# #### Colaboración y Responsabilidad Colectiva
#
# Es importante que todos los actores, desde individuos hasta grandes empresas y entidades gubernamentales, estén preparados para enfrentar los desafíos de la seguridad cibernética.
#
# - **Consecuencias:** De lo contrario, podrían enfrentar pérdidas financieras, daños a la reputación y responsabilidades legales.
#
# - **Mantenimiento y Actualización:** Por ende, es fundamental garantizar el mantenimiento y la actualización de los protocolos de seguridad, así como seguir las prácticas recomendadas para el cuidado de los datos informáticos, con el fin de mitigar los riesgos asociados con los ataques cibernéticos.
#
# Es relevante comprender que la seguridad en línea es una **responsabilidad compartida** entre los usuarios y los proveedores de servicios. Tanto las **empresas privadas** como las **entidades gubernamentales** deben asegurar la **actualización** y el **mantenimiento de los protocolos de seguridad**. Los **usuarios**, por su parte, deben seguir **prácticas recomendadas para proteger sus datos informáticos**. Esta colaboración nos ayuda para mantener un **entorno digital seguro y protegido**.
#
# ---
#
# ## **Justificación del Proyecto**
#
# El contexto resalta la necesidad de desarrollar herramientas robustas que faciliten la **toma de decisiones**, la **detección de vulnerabilidades** y la **elaboración de predicciones** en el ámbito de la ciberseguridad, estableciendo así las bases para **prevenir y actuar de manera efectiva** ante los crecientes **ataques cibernéticos**.
#
# El **análisis de datos** se posiciona como una herramienta que brinda una solución para cubrir estas necesidades de forma **rápida, eficiente y económica**. Además, ofrece resultados basados en datos del **mundo real**, convirtiéndolo en una alternativa altamente atractiva para afrontar los desafíos que suponen los ataques a la ciberseguridad.
#
# ---
#
# ## **Objetivos y Problemáticas Relacionadas**
#
# El proyecto tiene como objetivo principal la predicción y prevención de ataques de seguridad informática en las empresas mediante la creación de un modelo de Machine Learning. Este modelo se desarrollará utilizando las preguntas planteadas en la problemática como guía, con el fin de abordar de manera efectiva los desafíos de ciberseguridad identificados.
#
# #### Problemáticas Planteadas
#
# 1. **Tipos de Ciberataques:**
#    - **Pregunta:** ¿Cuáles son los tipos de ciberataques más frecuentes?
#    - **Objetivo:** Identificar los tipos de ataques que enfrentan las empresas para enfocar la estrategia de defensa en áreas específicas de vulnerabilidad.
#
# 2. **Navegadores Vulnerables:**
#    - **Pregunta:** ¿Cuáles son los navegadores con mayor nivel de vulnerabilidad?
#    - **Objetivo:** Determinar los navegadores más propensos a ser explotados por los atacantes, permitiendo a los usuarios tomar medidas proactivas para proteger sus sistemas.
#
# 3. **Correlación de Factores en Ataques:**
#    - **Pregunta:** ¿Cuál es la relación entre la ubicación del ataque, el puerto de conexión atacado, la gravedad del ataque y el navegador utilizado?
#    - **Objetivo:** Analizar la relación entre estos factores para identificar patrones y comprender mejor la dinámica de los ataques cibernéticos, lo que proporcionará información para fortalecer las defensas.
#
# 4. **Segmentos Vulnerados:**
#    - **Pregunta:** ¿Cuáles son los segmentos de la industria más afectados por ataques cibernéticos?
#    - **Objetivo:** Identificar los sectores más vulnerables a fin de dirigir los recursos de seguridad de manera eficiente y desarrollar medidas específicas para proteger estos segmentos.
#
# 5. **Reacción del Usuario:**
#    - **Pregunta:** ¿Cómo reacciona el usuario frente a una ciberamenaza?
#    - **Objetivo:** Comprender el comportamiento del usuario para mejorar la respuesta a las ciberamenazas, brindar formación en seguridad adaptada a las necesidades específicas y promover una cultura de ciberseguridad dentro de las organizaciones.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Excelente trabajo con el uso de markdown y la documentación en la introducción. Han hecho un buen trabajo con los separadores y los diferentes headers. En la sección de preuntas y objetivos es más que suficiente con lo que han planteado.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Comentario del revisor</b>
#     <br>
#     <b>Pregunta 1:</b> Sería útil incluir ejemplos específicos de tipos de ciberataques frecuentes para proporcionar contexto adicional y facilitar la identificación y comprensión de estos ataques.
#     <br>
#     <b>Pregunta 2:</b> Para evaluar la vulnerabilidad de los navegadores, sugiero considerar el uso de un puntaje de anomalía en lugar de la información sobre el navegador. Además, sería beneficioso incluir el tipo de dispositivo (endpoint) para comprender mejor la exposición potencial de los usuarios.
#     <br>
#     <b>Pregunta 3:</b> La correlación tradicionalmente se aplica a variables numéricas continuas, sin embargo, dado que hay múltiples variables categóricas en su caso, podría ser difícil aplicar la correlación de Pearson. Sugiero considerar el análisis de series de tiempo mediante la descomposición de series de tiempo para examinar patrones temporales en la frecuencia de ataques. También podrían explorar pruebas como la prueba chi-cuadrado para analizar la relación entre variables categóricas.
#     <br>
#     <b>Pregunta 4:</b> La pregunta sobre los segmentos de la industria afectados por ataques cibernéticos es excelente, aunque puede ser más fácil responder sobre la ubicación geográfica afectada en lugar de los sectores específicos de la industria.
#     <br>
#     <b>Pregunta 5:</b> La pregunta sobre la reacción del usuario frente a las ciberamenazas es sólida y puede proporcionar información valiosa para mejorar la conciencia y la formación en seguridad dentro de las organizaciones.
# </div>

# %%
# Paso 1: Importar Bibliotecas
# ---------------------------
# Importamos las bibliotecas necesarias para el análisis de datos.

import pandas as pd           # - pandas (pd): manipulación y análisis de datos.
import numpy as np            # - numpy (np): operaciones matemáticas.
import matplotlib.pyplot as plt  # - matplotlib.pyplot (plt): crear visualizaciones estáticas, como gráficos y diagramas.
import seaborn as sns         # - seaborn (sns): proporciona estilos y funciones adicionales para visualizaciones más atractivas.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# <br>
# Quería felicitarte por mantener las librerías por separado, ¡eso es genial! Además, me impresiona tu proactividad para documentar todo claramente.
# <br>
# Sin embargo, quería compartir contigo una sugerencia: En el código de producción, a menudo se evita agregar demasiados comentarios. Esto se debe a que pueden complicar los procesos de gestión de commits y cambios de línea. Especialmente los comentarios detallados sobre las paqueterías que son algo universales por ahora, ¡pero seguro que con el tiempo lograrás un balance entre qué tanta documentación requerimos.!
# </div>

# %%
# Configuración de Pandas
pd.set_option('display.max_columns', None)  # Muestra todas las columnas
pd.set_option('display.width', 1000)        # Opcional: ancho máximo del display

# Habilitar Matplotlib inline
# %matplotlib inline

# Configuración de estilos de Matplotlib y Seaborn
plt.style.use('ggplot')              # Estilo ggplot de Matplotlib
sns.set_style("whitegrid")           # Estilo whitegrid de Seaborn

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Te aconsejo agregar una sección de configuraciones adicionales para tu notebook. En el caso de tus dataframe era dificíl visualizar las columnas que quedaban en medio
# </div>

# %%
# Paso 2: Cargar el DataFrame desde un archivo CSV
# ------------------------------------------------
# Utilizamos pandas (pd) para leer un archivo CSV desde una URL y cargarlo en un DataFrame llamado 'df_cyberattacks'.
# La URL apunta a un conjunto de datos de ciberseguridad alojado en GitHub, que contiene información sobre ataques cibernéticos y que se obtuvo de Kaggle

df_cyberattacks = pd.read_csv('https://raw.githubusercontent.com/wtshnadeath/Cyber-Security-Attacks/main/cybersecurity_attacks.csv')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# <br>
# Buen trabajo con el estilo snake_case para tus variables, recuerda mantener siempre los datasets en una celda diferente para su carga. Pues re-cargarlos es algo que hacemos muy seguido.
# </div>

# %%
# Paso 3: Visualizar los Primeros Registros del DataFrame
# ------------------------------------------------------
# El método head muestra los primeros registros del DataFrame 'df_cyberattacks', dando un vistazo preliminar de los datos.

df_cyberattacks.head()
# Out:
#              Timestamp Source IP Address Destination IP Address  Source Port  Destination Port Protocol  Packet Length Packet Type Traffic Type                                       Payload Data Malware Indicators  Anomaly Scores  Alerts/Warnings Attack Type Attack Signature Action Taken Severity Level User Information                                 Device Information Network Segment   Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts Log Source
# 0  2023-05-30 06:33:58     103.216.15.12           84.9.164.252        31225             17616     ICMP            503        Data         HTTP  Qui natus odio asperiores nam. Optio nobis ius...       IoC Detected           28.67              NaN     Malware  Known Pattern B       Logged            Low    Reyansh Dugal  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment A  Jamshedpur, Sikkim      150.9.97.135      Log Data            NaN     Server
# ...

# %%
# Paso 4: Información Detallada del DataFrame
# -------------------------------------------
# Proporcionamos información detallada sobre las columnas y los tipos de datos en el DataFrame 'df_cyberattacksf' mediante el método index ().
df_cyberattacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               40000 non-null  object
#  1   Source IP Address       40000 non-null  object
#  2   Destination IP Address  40000 non-null  object
#  3   Source Port             40000 non-null  int64
#  4   Destination Port        40000 non-null  int64
#  5   Protocol                40000 non-null  object
#  6   Packet Length           40000 non-null  int64
#  7   Packet Type             40000 non-null  object
#  8   Traffic Type            40000 non-null  object
#  9   Payload Data            40000 non-null  object
#  10  Malware Indicators      20000 non-null  object
#  11  Anomaly Scores          40000 non-null  float64
#  12  Alerts/Warnings         19933 non-null  object
#  13  Attack Type             40000 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>Comentarios del Revisor</b> <a class="tocSkip"></a><br>
# Correcto, info(), head() y describe() son herramientas esceneciales que nos ayudaran a hacer un análisis exploratorio inicial. Continúa con el buen trabajo! </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Comentarios del Revisor</b> <a class="tocSkip"></a><br>
# En cuanto al nombre de las columnas del dataset. Es una buena práctica utilizar snake_case. Por ejemplo, source_port en vez de Source Port. Esto te permitirá realizar más operaciones y más fáciles en tus columnas.</div>

# %% [markdown]
# ## **Información General del DataFrame Cyberattacks**
#
# El método `info()` de la librería Pandas nos ofrece una visión general de nuestro conjunto de datos. Nuestro DataFrame está compuesto por **25 columnas** y contiene **40,000 entradas**.
#
# De las 25 columnas:
# - **21 son del tipo de variable objeto**, que generalmente contiene texto.
# - **3 columnas son del tipo int64**, que representan números enteros.
# - **1 columna es del tipo float64**, que contiene valores numéricos continuos.
#
# Se identificaron **5 columnas con posibles valores ausentes o nulos**: *IDS/IPS Alerts*, *Firewall Logs*, *Proxy Information*, *Alerts/Warnings* y *Malware Indicators*. Estas columnas serán evaluadas durante el proceso de limpieza de datos para garantizar la integridad de nuestro análisis.

# %%
# Paso 5: Dimensiones del DataFrame
# ---------------------------------
# Obtener las dimensiones del DataFrame 'df_cyberattacks', es decir, el número de filas y columnas con la función shape.

df_cyberattacks.shape
# Out:
# (40000, 25)

# %%
# Paso 6: Descripción Estadística del DataFrame
# --------------------------------------------
# Proporcionar información estadística descriptiva básica sobre el DataFrame 'df_cyberattacks'.

df_cyberattacks.describe()
# Out:
#         Source Port  Destination Port  Packet Length  Anomaly Scores
# count  40000.000000      40000.000000   40000.000000    40000.000000
# mean   32970.356450      33150.868650     781.452725       50.113473
# std    18560.425604      18574.668842     416.044192       28.853598
# min     1027.000000       1024.000000      64.000000        0.000000
# 25%    16850.750000      17094.750000     420.000000       25.150000
# 50%    32856.000000      33004.500000     782.000000       50.345000
# 75%    48928.250000      49287.000000    1143.000000       75.030000
# max    65530.000000      65535.000000    1500.000000      100.000000

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Comentarios del Revisor</b> <a class="tocSkip"></a><br>
# Buen intento. Pero hay que tener cuidado. Source Port y Destination Port no son variables númericas continuas. Son ariables categóricas pues describen los puertos de los diferentes equipos que se están analizando. </div>

# %%
# Paso 7: Identificación de Valores Nulos en el DataFrame
# ------------------------------------------------------
# Comprobamos la presencia de valores nulos en el DataFrame 'df_cyberattacks' y contamos la cantidad de nulos por columna.

# La función isnull() retorna un DataFrame booleano indicando la presencia de valores nulos.
# La función sum() aplicada a este DataFrame booleano suma los True (1) por columna, indicando el número de valores nulos en cada una.

df_cyberattacks.isnull().sum()
# Out:
# Timestamp                     0
# Source IP Address             0
# Destination IP Address        0
# Source Port                   0
# Destination Port              0
# Protocol                      0
# Packet Length                 0
# Packet Type                   0
# Traffic Type                  0
# Payload Data                  0
# Malware Indicators        20000
# Anomaly Scores                0
# Alerts/Warnings           20067
# Attack Type                   0
# Attack Signature              0
# Action Taken                  0
# Severity Level                0
# User Information              0
# Device Information            0
# Network Segment               0
# Geo-location Data             0
# Proxy Information         19851
# Firewall Logs             19961
# IDS/IPS Alerts            20050
# Log Source                    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor</b> <a class=“tocSkip”></a>
# . La verificación de valores ausentes te ayuda a comprender mejor tus datos y tomar decisiones informadas sobre cómo imputarlos. Recuerda siempre <b>calcular el porcentaje de valores ausentes con respecto al total</b>, ya que esto te dará una idea clara de su impacto en tu conjunto de datos. Sigue adelante con tu excelente trabajo y continúa explorando técnicas para mejorar tus análisis.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>Recomendación sobre Imputación de Datos</b> <a class="tocSkip"></a><br>
# Para asegurarte de que tus datos estén completos y listos para el análisis, te recomendaría considerar el uso de SimpleImputer de scikit-learn para manejar los valores faltantes en tu conjunto de datos. Esta herramienta es efectiva y fácil de implementar. En caso de que encuentres valores faltantes en tus variables, aquí hay algunas estrategias comunes para la imputación de datos:<br>
# <b>Imputación Media/Mediana:</b> Reemplazar los valores faltantes con el promedio o la mediana de la columna correspondiente. Esta estrategia es útil cuando los valores faltantes no siguen un patrón específico.<br>
# <b>Imputación por Moda:</b> Para variables categóricas, puedes reemplazar los valores faltantes con la moda, es decir, el valor más frecuente en esa columna.<br>
# <b>Imputación de Valores Constantes:</b> Si el valor faltante no representa información, puedes reemplazarlo con un valor constante que indique que la información no está disponible.<br>
#
# Recuerda evaluar el impacto de la imputación en el análisis posterior y seleccionar la estrategia que tenga más sentido en función de la naturaleza de tus datos y del problema que estás abordando. ¡Sigue adelante con tu trabajo y continúa con el análisis exploratorio detallado!
#
# </div>

# %%
# Paso 8: Eliminación de Filas con Valores Nulos en el DataFrame
# -------------------------------------------------------------
# Eliminamos las filas que contienen al menos un valor nulo en el DataFrame 'df_cyberattacks'.

# La función dropna() elimina las filas que contienen al menos un valor nulo.
# El parámetro inplace=True realiza la modificación directamente en el DataFrame original.

df_cyberattacks.dropna(inplace=True)

# %%
# Paso 9: Conteo de Valores Nulos en el DataFrame
# ----------------------------------------------
# Verificamos la cantidad de valores nulos por columna en el DataFrame 'df_cyberattacks'.

df_cyberattacks.isnull().sum()
# Out:
# Timestamp                 0
# Source IP Address         0
# Destination IP Address    0
# Source Port               0
# Destination Port          0
# Protocol                  0
# Packet Length             0
# Packet Type               0
# Traffic Type              0
# Payload Data              0
# Malware Indicators        0
# Anomaly Scores            0
# Alerts/Warnings           0
# Attack Type               0
# Attack Signature          0
# Action Taken              0
# Severity Level            0
# User Information          0
# Device Information        0
# Network Segment           0
# Geo-location Data         0
# Proxy Information         0
# Firewall Logs             0
# IDS/IPS Alerts            0
# Log Source                0
# dtype: int64

# %%
# Paso 10: Dimensiones Actuales del DataFrame después de Limpieza
# --------------------------------------------------------------
# Obtener las dimensiones actuales del DataFrame 'df_cyberattacks' después de la eliminación de filas con valores nulos.

df_cyberattacks.shape
# Out:
# (1237, 25)

# %%
# Paso 11: Identificación de Filas Duplicadas en el DataFrame
# ----------------------------------------------------------
# Contamos la cantidad de filas duplicadas en el DataFrame 'df_cyberattacks'.

# La función duplicated() retorna un DataFrame booleano que indica si cada fila es una duplicada de otra fila.
# La función sum() aplicada a este DataFrame booleano suma los True (1) por fila, indicando el número total de filas duplicadas.

df_cyberattacks.duplicated().sum()

# Fin de la limpieza de Datos
# Out:
# 0

# %%
# Paso 12: Cálculo de Estimados de Locación para Columnas Numéricas
# ----------------------------------------------------------------
# Definimos una lista de las columnas numéricas en el DataFrame y calculamos los estimados de locación para estas columnas.

# Lista de nombres de columnas numéricas que queremos analizar.
columnas_numericas = ['Source Port', 'Destination Port', 'Packet Length', 'Anomaly Scores'] #

# Calculamos la media y la mediana de los valores en estas columnas.
# - La media representa el valor promedio de los datos
# - La mediana es el valor que separa la mitad superior e inferior de los datos ordenados.

media_valores = df_cyberattacks[columnas_numericas].mean()  # Calculamos la media para cada columna numérica.
mediana_valores = df_cyberattacks[columnas_numericas].median()  # Calculamos la mediana para cada columna numérica.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Comentario del revisor</b>
# Sólo las últimas dos son númericas.
# </div>

# %%
# Paso 13: Cálculo de Estimados de Variabilidad para Columnas Numéricas
# ---------------------------------------------------------------------
# Definimos una lista de las columnas numéricas en el DataFrame y calculamos los estimados de variabilidad para estas columnas.

# Lista de nombres de columnas numéricas que queremos analizar.
columnas_numericas = ['Source Port', 'Destination Port', 'Packet Length', 'Anomaly Scores']

# Calculamos diferentes estimados de variabilidad para estas columnas.
# - El rango es la diferencia entre el valor máximo y mínimo en los datos.
# - La desviación estándar es una medida de la dispersión de los datos alrededor de la media.
# - El rango intercuartílico (IQR) es la diferencia entre el tercer y primer cuartil.

# Calculamos el rango, la desviación estándar y el IQR para cada columna numérica.
rango_valores = df_cyberattacks[columnas_numericas].max() - df_cyberattacks[columnas_numericas].min()  # Calculamos el rango.
desviacion_estandar_valores = df_cyberattacks[columnas_numericas].std()  # Calculamos la desviación estándar.
iqr_valores = df_cyberattacks[columnas_numericas].quantile(0.75) - df_cyberattacks[columnas_numericas].quantile(0.25)  # Calculamos el IQR.

# %%
# Paso 14: Creación de un DataFrame de Resultados
# ----------------------------------------------
# Creamos un DataFrame llamado 'resultados' que contiene los estimados de locación y variabilidad para las columnas numéricas.

# Creamos el DataFrame 'resultados' con las siguientes columnas:
# - 'Media': contiene los valores de media calculados previamente.
# - 'Mediana': contiene los valores de mediana calculados previamente.
# - 'Rango': contiene los valores de rango calculados previamente.
# - 'Desviación Estándar': contiene los valores de desviación estándar calculados previamente.
# - 'IQR': contiene los valores de rango intercuartil (IQR) calculados previamente.

resultados = pd.DataFrame({
    'Media': media_valores,
    'Mediana': mediana_valores,
    'Rango': rango_valores,
    'Desviación Estándar': desviacion_estandar_valores,
    'IQR': iqr_valores
})

# Mostramos el DataFrame 'resultados' que resume los estimados de locación y variabilidad.
print(resultados)
# Out:
#                          Media   Mediana     Rango  Desviación Estándar      IQR
# Source Port       33930.291027  35259.00  64384.00         18731.627558  32294.0
# Destination Port  33388.203719  33574.00  64410.00         18599.370814  32641.0
# Packet Length       784.832660    791.00   1436.00           419.686322    743.0
# Anomaly Scores       50.048593     48.99     99.95            28.754095     48.2

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
# Cuando usas `print()` para DataFrames en Jupyter Notebooks, pierdes los beneficios del formato HTML integrado. `display()` o simplemente dejar el DataFrame en una celda muestra los datos con un estilo más claro y ordenado, aprovechando las capacidades HTML de Jupyter. Esto facilita la interpretación y análisis de los datos, especialmente para tablas grandes o complejas.
# </div>

# %%
# Paso 15: Creación de Diagramas de Caja para Columnas Numéricas
# ------------------------------------------------------------

# Definimos las columnas numéricas que deseamos visualizar en el diagrama de caja.
primeras_columnas = ['Source Port', 'Destination Port']

# Creamos una nueva figura para el diagrama de caja y especificamos su tamaño.
plt.figure(figsize=(10, 6))  # Anchura de 10 pulgadas y altura de 6 pulgadas.

# Generamos el diagrama de caja utilizando los datos de las columnas especificadas en primeras_columnas del DataFrame df_cyberattacks.
sns.boxplot(data=df_cyberattacks[primeras_columnas], palette="rocket_r")  # Usamos un estilo de color "rocket_r".

# Establecemos un título para el diagrama de caja.
plt.title('Diagrama de Caja para Puertos de Origen y Destino')  # Titulamos el diagrama de caja.

# Etiquetamos el eje X del diagrama de caja.
plt.xlabel('Columnas Numéricas')  # Nombramos el eje x como "Columnas Numéricas".

# Etiquetamos el eje Y del diagrama de caja.
plt.ylabel('Valores')  # Nombramos el eje y como "Valores".

# Mostramos el diagrama de caja.
plt.show()  # Visualizamos la figura.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Comentario del revisor</b>
# Buen intento con la gráfica, pero recuerda que no nos será tan útil.
# </div>

# %%
# Paso 16: Creación de un Diagrama de Caja para una Columna Numérica
# -------------------------------------------------------------------

# Seleccionamos la columna numérica que deseamos visualizar en el diagrama de caja.
tercera_columna = ['Packet Length']

# Establecemos el tamaño de la figura para el diagrama de caja.
plt.figure(figsize=(10, 6))  # Anchura de 10 pulgadas y altura de 6 pulgadas.

# Creamos el diagrama de caja utilizando seaborn.
sns.boxplot(data=df_cyberattacks[tercera_columna], palette=sns.color_palette(["#1f77b4"]))  # Tono de azul oscuro

# Personalizamos las etiquetas de los ejes y el título.
plt.title('Diagrama de Caja para la Longitud de Paquetes de Datos')  # Titulamos el diagrama de caja.
plt.xlabel('Columna Numérica')  # Nombramos el eje x como "Columna Numérica".
plt.ylabel('Valores')  # Nombramos el eje y como "Valores".

# Mostramos el diagrama de caja.
plt.show()  # Visualizamos la figura.

# %%
# Paso 16: Creación de un Diagrama de Caja para una Columna Numérica
# -------------------------------------------------------------------

# Seleccionamos la cuarta columna numérica para el diagrama de caja.
cuarta_columna = ['Anomaly Scores']  # 'Anomaly Scores' contiene los puntajes de anomalía.

# Definimos un color personalizado para el diagrama de caja.
color_personalizado = '#FF6747'  # Código hexadecimal para un tono de rojo brillante.

# Establecemos el tamaño de la figura de Matplotlib para el diagrama de caja.
plt.figure(figsize=(10, 6))  # Anchura de 10 pulgadas y altura de 6 pulgadas.

# Creamos el diagrama de caja utilizando seaborn, específicamente para la columna de anomalía de puntajes.
sns.boxplot(data=df_cyberattacks[cuarta_columna], color=color_personalizado)

# Personalizamos las etiquetas de los ejes y el título para una mejor comprensión.
plt.title('Diagrama de Caja para la Anomalía de Puntajes')  # Título del gráfico
plt.ylabel('Valores')  # Etiqueta del eje y, que representa los valores en el diagrama de caja

# Mostramos el diagrama de caja.
plt.show()  # Visualizamos la figura.

# %% [markdown]
# ###**Visualización de Datos**
#
# Realizamos visualizaciones utilizando diagramas de caja para explorar posibles valores atípicos en nuestras columnas numéricas, como "*Packet Length*" y "*Anomaly Scores*". Sin embargo, nuestros análisis no revelaron la presencia de valores atípicos significativos en el conjunto de datos de ciberataques.
#
# ###**Conclusiones**
#
# Basándonos en nuestro análisis visual, no encontramos evidencia que indique la presencia de valores atípicos en nuestro conjunto de datos de ciberataques. Por lo tanto, no consideramos necesario realizar ninguna depuración de datos en esta etapa del proyecto.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
# Ten cuidado con nuestro código markdown en esta sección! </div>

# %%
# Paso 17: Creación de una Gráfica de Barras para la Frecuencia de Tipos de Ataques
# ---------------------------------------------------------------------------------

# Calculamos la frecuencia de cada tipo de ataque en el DataFrame.
attack_type_counts = df_cyberattacks['Attack Type'].value_counts()

# Establecemos el tamaño de la figura para la gráfica de barras.
plt.figure(figsize=(8, 6))  # Anchura de 10 pulgadas y altura de 6 pulgadas.

# Creamos la gráfica de barras para visualizar la frecuencia de cada tipo de ataque.
attack_type_counts.plot(kind='bar', color='#FF5733')  # Utilizamos un color naranja para representar los ataques.

# Personalizamos las etiquetas de los ejes y el título.
plt.title('Frecuencia de Tipos de Ataques')
plt.xlabel('Tipo de Ataque')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45, ha='right')  # Rotamos las etiquetas del eje x para una mejor legibilidad.
plt.tight_layout()  # Ajustamos el diseño para evitar superposiciones.

# Mostramos la gráfica de barras.
plt.show()  # Visualizamos la figura.

# %%
# Paso 18: Conteo de Frecuencia de Tipos de Ataque
# ------------------------------------------------

# Calculamos la frecuencia de cada tipo de ataque utilizando el método value_counts() de pandas.
frec_attack_tab = pd.value_counts(df_cyberattacks['Attack Type'])

# La variable 'frec_attack_tab' contiene la frecuencia de cada tipo de ataque.
# Este paso es para comprender la distribución de los tipos de ataques en los datos.

# Mostramos los resultados para visualizar la frecuencia de cada tipo de ataque.
frec_attack_tab
# Out:
# Intrusion    419
# Malware      414
# DDoS         404
# Name: Attack Type, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Gracias por enviar tu proyecto. Has hecho un excelente trabajo.
# Has respondido correctamente a la mayoría de las preguntas que planteaste, aunque espacio para mejorar.
#
# Destaco de tu trabajo que has sido muy extensa en la documentación , recuerda encontrar un balance en la siguiente iteración,  Y vas en buen camino con la exploración gráfica.
#
# Creo que tu proyecto es un buen candidato para centrarnos en el aspecto descriptivo. De varios diagramas y gráficos.
# A futuro puedes implementar seríes de tiempo y hacer predicciones sobre la cantidad de ataques que se observaran.
# El clustering puede ayudarte para ver como se agrupan los diversos ataques. Y finalmente y quizá un poco más dificíl sea hacer clasificación.
#
#
# Pueden documentarse más sobre herramientas de ciberseguridad como Crowdstrike,  Microsoft Defener, son sistemas EDR que ofrecen dashoboards y análisis sobre amenazas cibernéticas.
# Ánimo, estoy seguro de que vas por un muy buen camino.
#
#
# Gracias por su trabajo. &#128077;<br>
# <img src="https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExNG95b2U5Y24xaHF0bjg1c3ZxdXUwOGZuMjczbzJqazBleTdneXJ1ZiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/LYRSRTWa9oD8fdvV4C/giphy.gif" alt="Gif de ánimo">
#
# </div>
